# %% [markdown]
# <a href="https://colab.research.google.com/github/PACE1000/XOR-Gate-Backpropagation/blob/main/Alif%20Rachmat%20Illahi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print(bytes.fromhex("584f52204e657572616c204e6574776f726b2064656e67616e204d65746f646520534744206d656e6767756e616b616e2054656e736f72666c6f772064616e204b65726173").decode("utf-8"))
print(bytes.fromhex("4e617566616c205961666920537573616e746f2028323130363031323031323030313129").decode("utf-8"))
print(bytes.fromhex("4e6164686966204c617a75617264692041756c696120526168696d2028323130363031323031323030303429").decode("utf-8"))
print(bytes.fromhex("4d7568616d616420486166697a6820426169686171692028323130363031323031343030393029").decode("utf-8"))
print(bytes.fromhex("4d7568616d6d61642052697a71692053616661e2809961742028323130363031323031343030393729").decode("utf-8"))
# Out:
# XOR Neural Network dengan Metode SGD menggunakan Tensorflow dan Keras
# Naufal Yafi Susanto (21060120120011)
# Nadhif Lazuardi Aulia Rahim (21060120120004)
# Muhamad Hafizh Baihaqi (21060120140090)
# Muhammad Rizqi Safa’at (21060120140097)

# %%
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt

# %%
inputs = np.array([[0,0],
                   [0,1],
                   [1,0],
                   [1,1]])

targets = np.array([0,1,1,0])

# %%
model = keras.models.Sequential([
    keras.layers.Dense(units=2,activation='linear',input_shape=(2,)),
    keras.layers.Dense(units=2,activation='sigmoid'),
    keras.layers.Dense(units=1,activation='linear'),
    ]
)

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 2)                 6
#
#  dense_1 (Dense)             (None, 2)                 6
#
#  dense_2 (Dense)             (None, 1)                 3
#
# ...
# Total params: 15
# Trainable params: 15
# Non-trainable params: 0
# _________________________________________________________________

# %%
sgd = keras.optimizers.SGD(learning_rate=0.5)
model.compile(optimizer=sgd, loss='mse')

# %%
outputs = model.fit(inputs,
                    targets,
                    epochs=500)

loss_values = outputs.history['loss']

plt.plot(loss_values)
plt.title('Training Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()
# Out:
# Epoch 1/500
# 1/1 [==============================] - 1s 1s/step - loss: 0.8956
# Epoch 2/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.2912
# Epoch 3/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2454
# Epoch 4/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.2442
# Epoch 5/500
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2439
# Epoch 6/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2437
# Epoch 7/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2435
# Epoch 8/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.2432
# Epoch 9/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.2429
# Epoch 10/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.2427
# Epoch 11/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2424
# Epoch 12/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2421
# ...

# %%
predict = model.predict(inputs)
print(["%.3f" % x for x in np.nditer(predict)])
# Out:
# 1/1 [==============================] - 0s 188ms/step
# ['0.000', '1.000', '1.000', '0.000']

# %%
weights = model.weights
for weight in weights:
    weight_values = weight.numpy()
    print(weight.name, weight_values, sep="\n", end="\n\n")
# Out:
# dense/kernel:0
# [[ 2.302003   -0.94370395]
#  [ 1.777893    1.0094453 ]]
#
# dense/bias:0
# [-0.98878294 -0.52616876]
#
# dense_1/kernel:0
# [[-3.1257112  -1.176719  ]
#  [-0.4439024  -0.26532677]]
#
# dense_1/bias:0
# [-0.20850016  1.4672518 ]
#
# dense_2/kernel:0
# [[-1.9558182]
#  [ 2.2649417]]
#
# dense_2/bias:0
# [-0.2586649]
